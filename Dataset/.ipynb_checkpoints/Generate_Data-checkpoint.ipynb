# %% [markdown]
# # Creation of the Dataset

# %% [markdown]
# ### Importations

# %%
import numpy as np
import matplotlib.pyplot as plt
import IPython
import pyroomacoustics as pra
import pickle as pkl
import pandas as pd
from scipy.io import wavfile
from scipy.signal import fftconvolve
from scipy import signal
from matplotlib import gridspec

# %% [markdown]
# ### Function that computes the absorption out of the room dimensions and the RT60.

# %%
def compute_absorption(room_eadge,room_height,RT60):
    V = (room_eadge**2)*room_height
    S = 2*(room_eadge**2) + 4*(room_height**2)
    absr = 0.1611*(V/(S*RT60))
    return absr

# %% [markdown]
# ### Setting the different parameters for the rooms

# %%
#Here You should put the path to where the file wav is on the machine you are working on.
folder_path = "/home/janjar/Semester_Project/Dataset/GDWN/WGN.wav"
file_to_open = folder_path 

ang = (np.array([61.]) / 180.) * np.pi
distance = 1.0
a = np.array([5.,5.,3.])
b = np.array([6.,6.,3.])
dimensions = np.stack((a,b))
distances = np.array([1.,2.])
RT60 = np.array([0.2,0.3])

absorption_1 = compute_absorption(a[0],a[2],RT60[0])
absorption_2 = compute_absorption(b[0],b[2],RT60[1])
absorptions = np.array([absorption_1,absorption_2])
print(absorptions.shape)

snr = 5.
fs,signal_wav = wavfile.read(file_to_open)
snrs = np.array([5,10,15,20])
# Out:
# (2,)

# %% [markdown]
# ## Methode that generates a room out of the conditions given in argument.
# ### Returns the audio_signals for the 4 mics, the location of the source and the absorption of the room .

# %%
def generate_room_from_conditions(ang,distance,absorptions,snr,dimensions,typeofroom):
   
    room_dim = dimensions[typeofroom]
    room_eadge = room_dim[0]

    sf = (0.03*np.sqrt(2)/4)
    corners = np.array([[0,0],[0,room_eadge],[room_eadge,room_eadge],[room_eadge,0]]).T
    
    absr = absorptions[typeofroom]
    room = pra.Room.from_corners(corners, fs=fs , max_order=8 ,absorption=absorptions[typeofroom])
    room.extrude(3.)

    # Add sources of 1 second duration
    #room_dim = np.array([5,5,3])
    rng = np.random.RandomState(23)
    duration_samples = int(fs)


    source_location = room_dim / 2 + (distance * np.array([np.cos(ang), np.sin(ang),0.0]))
    source_signal = rng.randn(duration_samples)
    room.add_source(source_location, signal = signal_wav)
    print('Here is the source at this step:',source_location) 

    #We initiate the point of the Tethra then we scale them
    #and translate the origin of the Tethra to the center of the room.
    R = np.array([(sf*np.array([1,1,-1,-1]))+2.5,(sf*np.array([1,-1,1,-1]))+2.5,(sf*np.array([1,-1,-1,1]))+1.5])# [[x], [y], [z]]
    room.add_microphone_array(pra.MicrophoneArray(R,room.fs))
    room.image_source_model(use_libroom=True)

    #Visualization
    #fig, ax = room.plot(img_order=3)
    #fig.set_size_inches(18.5,10.5)

    room.simulate(snr = snr)
    #print('Here is the audio signal:',room.mic_array.signals[0][:5])
    return room.mic_array.signals,source_location,absr

# %% [markdown]
# ### Testing that generate_room works properly

# %%
ang = (np.array([61.]) / 180.) * np.pi
audio_signals,source_loc,t = generate_room_from_conditions(ang,distances[0],absorptions,snr,dimensions,0)
print(audio_signals[0,:].shape)
# Out:
# Here is the source at this step: [array([2.98480962]) array([3.37461971]) 1.5]
# (49702,)

# %% [markdown]
# ## Method that compute the phasematrix out of a signal and store it in the training folder.
# ### Returns the paths to the audio_file and the phase_matrix.

# %%
def generate_phasematrix_from_signals(signals,j):
    
    #Here also the path should be the folder you need the audio files to be stored on.
        path = "/home/janjar/Dataset/Trainingset/"   
        name_signals = 'audio_signals/audio_signals-{}'.format(j)
        fileName_audio = path + name_signals
        fileObject = open(fileName_audio, 'wb')
        pkl.dump(signals, fileObject)
        fileObject.close()                
    
        phase_matrix = np.empty((4, 129, 390))
        for i in range(4):
            f, t, stft_mic0 = signal.stft(audio_signals[i,:].astype(np.float32), fs)
            spectrum = stft_mic0
            magnitude = np.abs(spectrum)
            phase = np.angle(spectrum)
            #print('Here is the phase:',phase)
            x = phase.shape[0]
            y = phase.shape[1]
            #print("HERE IS THE SHAPE",phase.shape)
            #phase_matrix = np.empty((4, x, y))
            phase_matrix[i] = phase
            
        path = "/home/janjar/Dataset/Trainingset/"   
        name_matrix = 'phase_matrix/Phase_matrix-{}'.format(j)
        fileName_matrix = path + name_matrix
        fileObject = open(fileName_matrix, 'wb')
        pkl.dump(phase_matrix, fileObject)
        fileObject.close()                    
        return fileName_audio,fileName_matrix

# %% [markdown]
# ### Testing that generate_phasematrix works properly

# %%
path_to_matrix = generate_phasematrix_from_signals(audio_signals,0)
print(path_to_matrix)
# Out:
# ('/home/janjar/Dataset/Trainingset/audio_signals/audio_signals-0', '/home/janjar/Dataset/Trainingset/phase_matrix/Phase_matrix-0')

# %% [markdown]
# ### Funtion to assign the right label to each angle.

# %%
def assign_label_to_anlges(angles):
	bins = np.linspace(0, 180, 37)
	label = np.digitize(angles, bins)
	return label

# %% [markdown]
# ## The main function that generate the entire Dataset set including the Dataframe to represent it.
# ### Return the Dataframe representing the training set.

# %%
def genere_dataset():
        index = 0
        df = pd.DataFrame(columns = ['Room','Array_position','Distance','Absorption','SNR','Audio_file','Phase_Matrix','Label'])
        snr = np.array([0,5,10,15,20]) #Comment this part to turn the snr into random assignment for each room
	#We iterate over the type of rooms (R1,R2).
        for i in range (2):          
	#We iterate over the distances from the microphones (1m,2m).	
            for j in range(2):
    #We iterate over the 5 different SNRS.       
                for l in range(5):    
	#We iterate on the 7 random positions of the source.		
                    for k in range(7):
                        print('Room:',index)
                        angles = np.random.uniform(low=0, high=180, size=(7,))
                        #print('Here are the angles for this Room:',angles) #Make the angles able to go to floats.
                        labels = assign_label_to_anlges(angles)
                        #print('Here are the labels for this Room:',labels) #Check if the labels match the angles.
                        azimuth = angles / 180. * np.pi 
                        #snr = snrs[np.random.randint(4,size = 1)] # Uncomment this part to turn the snr into random assignment for each room
                        signals,array_position,absr = generate_room_from_conditions(angles[k],distances[j],absorptions,snr[l],dimensions,i)
                        fileName_audio,fileName_matrix = generate_phasematrix_from_signals(signals,index)
                        df = df.append({'Room':i,'Array_position':array_position,'Distance':distances[j],'Absorption':absr,'SNR':snr[l],'Audio_file':fileName_audio,'Phase_Matrix':fileName_matrix,'Label':labels[k]} , ignore_index=True)
                        index = index+1
        return df

# %%
Dataset = genere_dataset()
# Out:
# Room: 0
# Here is the source at this step: [3.39554561 2.05503027 1.5       ]
# Room: 1
# Here is the source at this step: [3.24021072 1.82762503 1.5       ]
# Room: 2
# Here is the source at this step: [1.68010679 1.92748352 1.5       ]
# Room: 3
# Here is the source at this step: [3.20652691 3.20768617 1.5       ]
# Room: 4
# Here is the source at this step: [3.4905783  2.36305248 1.5       ]
# Room: 5
# Here is the source at this step: [1.50122304 2.45055725 1.5       ]
# Room: 6
# Here is the source at this step: [3.39489893 2.94626888 1.5       ]
# Room: 7
# Here is the source at this step: [1.6497652  3.02640363 1.5       ]
# Room: 8
# Here is the source at this step: [3.47717898 2.28758238 1.5       ]
# Room: 9
# Here is the source at this step: [2.1672115  3.44300149 1.5       ]
# Room: 10
# Here is the source at this step: [1.98058794 1.64547609 1.5       ]
# Room: 11
# Here is the source at this step: [3.00381353 3.36381244 1.5       ]
# Room: 12
# Here is the source at this step: [2.99313221 3.36995438 1.5       ]
# Room: 13
# Here is the source at this step: [1.66425026 3.04911052 1.5       ]
# Room: 14
# Here is the source at this step: [3.40386834 2.92781074 1.5       ]
# Room: 15
# Here is the source at this step: [3.48991005 2.35830278 1.5       ]
# Room: 16
# Here is the source at this step: [2.87101282 1.57137225 1.5       ]
# Room: 17
# Here is the source at this step: [1.61542914 2.96640583 1.5       ]
# Room: 18
# Here is the source at this step: [3.37844748 2.97783891 1.5       ]
# Room: 19
# Here is the source at this step: [3.39480092 2.94646535 1.5       ]
# Room: 20
# Here is the source at this step: [2.58651858 1.50374976 1.5       ]
# Room: 21
# Here is the source at this step: [3.14641707 3.26298426 1.5       ]
# Room: 22
# Here is the source at this step: [1.61614901 2.03223144 1.5       ]
# Room: 23
# Here is the source at this step: [3.48843115 2.65167022 1.5       ]
# Room: 24
# Here is the source at this step: [3.39790801 2.05981684 1.5       ]
# Room: 25
# Here is the source at this step: [3.4552134  2.79591781 1.5       ]
# Room: 26
# Here is the source at this step: [1.71273413 3.11661369 1.5       ]
# Room: 27
# Here is the source at this step: [3.36465859 3.00235995 1.5       ]
# Room: 28
# Here is the source at this step: [1.58778196 2.90970507 1.5       ]
# Room: 29
# Here is the source at this step: [1.79619853 1.78960329 1.5       ]
# Room: 30
# Here is the source at this step: [3.47832315 2.70708407 1.5       ]
# Room: 31
# Here is the source at this step: [1.88109511 1.71453407 1.5       ]
# Room: 32
# Here is the source at this step: [2.26754072 1.52739387 1.5       ]
# Room: 33
# Here is the source at this step: [2.94140388 3.39730854 1.5       ]
# Room: 34
# Here is the source at this step: [2.56775504 1.50229801 1.5       ]
# Room: 35
# Here is the source at this step: [0.86582098 3.65302165 1.5       ]
# Room: 36
# Here is the source at this step: [3.84963297 3.97597115 1.5       ]
# Room: 37
# Here is the source at this step: [1.92934815 0.5831389  1.5       ]
# Room: 38
# Here is the source at this step: [0.77309433 1.49114085 1.5       ]
# Room: 39
# Here is the source at this step: [0.50000171 2.50261687 1.5       ]
# Room: 40
# Here is the source at this step: [3.9440974  3.88368447 1.5       ]
# Room: 41
# Here is the source at this step: [0.72152276 3.41488727 1.5       ]
# Room: 42
# Here is the source at this step: [3.40852295 4.28173681 1.5       ]
# Room: 43
# Here is the source at this step: [1.03708496 3.86377402 1.5       ]
# Room: 44
# Here is the source at this step: [1.89133274 0.59486899 1.5       ]
# Room: 45
# Here is the source at this step: [4.42522605 3.04176069 1.5       ]
# Room: 46
# Here is the source at this step: [2.72563346 4.48723163 1.5       ]
# Room: 47
# Here is the source at this step: [3.93206641 1.10386756 1.5       ]
# Room: 48
# Here is the source at this step: [4.475171   2.81416482 1.5       ]
# Room: 49
# Here is the source at this step: [4.47515766 2.81424865 1.5       ]
# Room: 50
# Here is the source at this step: [4.22406559 3.513705   1.5       ]
# Room: 51
# Here is the source at this step: [1.13927879 1.03424498 1.5       ]
# Room: 52
# Here is the source at this step: [4.4735998  2.82388863 1.5       ]
# Room: 53
# Here is the source at this step: [0.97267489 3.7912312  1.5       ]
# Room: 54
# Here is the source at this step: [2.80207912 4.47705544 1.5       ]
# Room: 55
# Here is the source at this step: [1.66877254 0.68091757 1.5       ]
# Room: 56
# Here is the source at this step: [1.71311469 0.66130168 1.5       ]
# Room: 57
# Here is the source at this step: [4.45126468 2.93882359 1.5       ]
# Room: 58
# Here is the source at this step: [4.16843591 1.39713028 1.5       ]
# Room: 59
# Here is the source at this step: [0.50007615 2.51745309 1.5       ]
# Room: 60
# Here is the source at this step: [0.52761146 2.83118491 1.5       ]
# Room: 61
# Here is the source at this step: [2.63366398 0.50447151 1.5       ]
# Room: 62
# Here is the source at this step: [0.72031408 1.58746616 1.5       ]
# Room: 63
# Here is the source at this step: [2.72319197 0.51249268 1.5       ]
# Room: 64
# Here is the source at this step: [4.47976426 2.78378421 1.5       ]
# Room: 65
# Here is the source at this step: [4.48427353 2.24968308 1.5       ]
# Room: 66
# Here is the source at this step: [2.70464177 0.51049711 1.5       ]
# Room: 67
# Here is the source at this step: [3.47033491 0.75115748 1.5       ]
# Room: 68
# Here is the source at this step: [3.65514185 0.86731898 1.5       ]
# Room: 69
# Here is the source at this step: [1.05045872 3.87798044 1.5       ]
# Room: 70
# Here is the source at this step: [3.75947905 3.65053176 1.5       ]
# Room: 71
# Here is the source at this step: [3.97836997 3.20686277 1.5       ]
# Room: 72
# Here is the source at this step: [2.34188338 3.75291601 1.5       ]
# Room: 73
# Here is the source at this step: [3.96497064 2.73764209 1.5       ]
# Room: 74
# Here is the source at this step: [2.01081012 2.8533597  1.5       ]
# Room: 75
# Here is the source at this step: [2.2499912  2.33857215 1.5       ]
# Room: 116
# Here is the source at this step: [4.97052052 3.34212406 1.5       ]
# Room: 117
# Here is the source at this step: [4.80244103 2.13327839 1.5       ]
# Room: 118
# Here is the source at this step: [4.99742887 2.89861997 1.5       ]
# Room: 119
# Here is the source at this step: [2.96754746 1.00026331 1.5       ]
# Room: 120
# Here is the source at this step: [1.72542173 4.54124957 1.5       ]
# Room: 121
# Here is the source at this step: [2.07954939 1.22439569 1.5       ]
# Room: 122
# Here is the source at this step: [1.35066066 1.86877069 1.5       ]
# Room: 123
# Here is the source at this step: [4.98989784 3.20076496 1.5       ]
# Room: 124
# Here is the source at this step: [3.32559947 1.02668173 1.5       ]
# Room: 125
# Here is the source at this step: [1.11384211 2.3348621  1.5       ]
# Room: 126
# Here is the source at this step: [4.54282848 4.2726666  1.5       ]
# Room: 127
# Here is the source at this step: [1.40343127 4.20456145 1.5       ]
# Room: 128
# Here is the source at this step: [2.82634319 1.00755344 1.5       ]
# Room: 129
# Here is the source at this step: [3.32029447 4.97418628 1.5       ]
# Room: 130
# Here is the source at this step: [3.30683541 1.02367714 1.5       ]
# Room: 131
# Here is the source at this step: [1.09770681 3.61747924 1.5       ]
# Room: 132
# Here is the source at this step: [4.99329456 3.16363617 1.5       ]
# Room: 133
# Here is the source at this step: [4.96296383 2.61689033 1.5       ]
# Room: 134
# Here is the source at this step: [4.36468398 1.53793378 1.5       ]
# Room: 135
# Here is the source at this step: [4.94010052 2.51419144 1.5       ]
# Room: 136
# Here is the source at this step: [3.41976331 1.04454641 1.5       ]
# Room: 137
# Here is the source at this step: [3.35322942 1.03143987 1.5       ]
# Room: 138
# Here is the source at this step: [1.16494859 2.20464704 1.5       ]
# Room: 139
# Here is the source at this step: [1.09607761 2.38756262 1.5       ]

# %%
Dataset
# Out:
#     Room                                 Array_position  Distance  Absorption  \
# 0      0   [3.395545610109257, 2.0550302704519794, 1.5]       1.0    0.702471
# 1      0  [3.2402107165724896, 1.8276250338752629, 1.5]       1.0    0.702471
# 2      0   [1.6801067878855174, 1.927483519251545, 1.5]       1.0    0.702471
# 3      0   [3.2065269137273935, 3.207686173511143, 1.5]       1.0    0.702471
# 4      0   [3.4905783048095183, 2.363052484357324, 1.5]       1.0    0.702471
# 5      0    [1.501223040575943, 2.450557252062255, 1.5]       1.0    0.702471
# 6      0   [3.3948989250213115, 2.946268880828253, 1.5]       1.0    0.702471
# 7      0   [1.649765195551367, 3.0264036258463607, 1.5]       1.0    0.702471
# 8      0    [3.477178978481561, 2.287582382995825, 1.5]       1.0    0.702471
# 9      0   [2.167211498186939, 3.4430014915476104, 1.5]       1.0    0.702471
# 10     0   [1.9805879445761017, 1.645476087707125, 1.5]       1.0    0.702471
# 11     0   [3.0038135301359947, 3.363812437310269, 1.5]       1.0    0.702471
# 12     0  [2.9931322124796136, 3.3699543786975044, 1.5]       1.0    0.702471
# 130    1  [3.3068354059998026, 1.0236771433733465, 1.5]       2.0    0.537000
# 131    1   [1.097706809655404, 3.6174792449698843, 1.5]       2.0    0.537000
# 132    1   [4.993294560638962, 3.1636361650954012, 1.5]       2.0    0.537000
# 133    1    [4.962963825212832, 2.616890327835739, 1.5]       2.0    0.537000
# 134    1    [4.364683982716124, 1.537933781486605, 1.5]       2.0    0.537000
# 135    1   [4.940100523213924, 2.5141914370607914, 1.5]       2.0    0.537000
# 136    1   [3.4197633138965844, 1.044546405483741, 1.5]       2.0    0.537000
# 137    1    [3.353229422628736, 1.031439872650731, 1.5]       2.0    0.537000
# 138    1  [1.1649485918953892, 2.2046470408596663, 1.5]       2.0    0.537000
# 139    1  [1.0960776140125528, 2.3875626169673625, 1.5]       2.0    0.537000
#
#     SNR                                         Audio_file  \
# 0     0  /home/janjar/Dataset/Trainingset/audio_signals...
# 1     0  /home/janjar/Dataset/Trainingset/audio_signals...
# 2     0  /home/janjar/Dataset/Trainingset/audio_signals...
# 3     0  /home/janjar/Dataset/Trainingset/audio_signals...
# 4     0  /home/janjar/Dataset/Trainingset/audio_signals...
# 5     0  /home/janjar/Dataset/Trainingset/audio_signals...
# 6     0  /home/janjar/Dataset/Trainingset/audio_signals...
# 7     5  /home/janjar/Dataset/Trainingset/audio_signals...
# 8     5  /home/janjar/Dataset/Trainingset/audio_signals...
# 9     5  /home/janjar/Dataset/Trainingset/audio_signals...
# 10    5  /home/janjar/Dataset/Trainingset/audio_signals...
# 11    5  /home/janjar/Dataset/Trainingset/audio_signals...
# 12    5  /home/janjar/Dataset/Trainingset/audio_signals...
# 13    5  /home/janjar/Dataset/Trainingset/audio_signals...
# 14   10  /home/janjar/Dataset/Trainingset/audio_signals...
# 15   10  /home/janjar/Dataset/Trainingset/audio_signals...
# 16   10  /home/janjar/Dataset/Trainingset/audio_signals...
# 17   10  /home/janjar/Dataset/Trainingset/audio_signals...
# 18   10  /home/janjar/Dataset/Trainingset/audio_signals...
# 19   10  /home/janjar/Dataset/Trainingset/audio_signals...
# 20   10  /home/janjar/Dataset/Trainingset/audio_signals...
# 21   15  /home/janjar/Dataset/Trainingset/audio_signals...
# 22   15  /home/janjar/Dataset/Trainingset/audio_signals...
# 23   15  /home/janjar/Dataset/Trainingset/audio_signals...
# 24   15  /home/janjar/Dataset/Trainingset/audio_signals...
# 25   15  /home/janjar/Dataset/Trainingset/audio_signals...
# 26   15  /home/janjar/Dataset/Trainingset/audio_signals...
# 27   15  /home/janjar/Dataset/Trainingset/audio_signals...
# 28   20  /home/janjar/Dataset/Trainingset/audio_signals...
# 29   20  /home/janjar/Dataset/Trainingset/audio_signals...
# ..   ..                                                ...
# 110   0  /home/janjar/Dataset/Trainingset/audio_signals...
# 111   0  /home/janjar/Dataset/Trainingset/audio_signals...
# 112   5  /home/janjar/Dataset/Trainingset/audio_signals...
# 113   5  /home/janjar/Dataset/Trainingset/audio_signals...
# 114   5  /home/janjar/Dataset/Trainingset/audio_signals...
# 115   5  /home/janjar/Dataset/Trainingset/audio_signals...
# 116   5  /home/janjar/Dataset/Trainingset/audio_signals...
# 117   5  /home/janjar/Dataset/Trainingset/audio_signals...
# 118   5  /home/janjar/Dataset/Trainingset/audio_signals...
# 119  10  /home/janjar/Dataset/Trainingset/audio_signals...
# 120  10  /home/janjar/Dataset/Trainingset/audio_signals...
# 121  10  /home/janjar/Dataset/Trainingset/audio_signals...
# 122  10  /home/janjar/Dataset/Trainingset/audio_signals...
# 123  10  /home/janjar/Dataset/Trainingset/audio_signals...
# 124  10  /home/janjar/Dataset/Trainingset/audio_signals...
# 125  10  /home/janjar/Dataset/Trainingset/audio_signals...
# 126  15  /home/janjar/Dataset/Trainingset/audio_signals...
# 127  15  /home/janjar/Dataset/Trainingset/audio_signals...
# 128  15  /home/janjar/Dataset/Trainingset/audio_signals...
# 129  15  /home/janjar/Dataset/Trainingset/audio_signals...
# 130  15  /home/janjar/Dataset/Trainingset/audio_signals...
# 131  15  /home/janjar/Dataset/Trainingset/audio_signals...
# 132  15  /home/janjar/Dataset/Trainingset/audio_signals...
# 133  20  /home/janjar/Dataset/Trainingset/audio_signals...
# 134  20  /home/janjar/Dataset/Trainingset/audio_signals...
# 135  20  /home/janjar/Dataset/Trainingset/audio_signals...
# 136  20  /home/janjar/Dataset/Trainingset/audio_signals...
# 137  20  /home/janjar/Dataset/Trainingset/audio_signals...
# 138  20  /home/janjar/Dataset/Trainingset/audio_signals...
# 139  20  /home/janjar/Dataset/Trainingset/audio_signals...
#
#                                           Phase_Matrix Label
# 0    /home/janjar/Dataset/Trainingset/phase_matrix/...    21
# 1    /home/janjar/Dataset/Trainingset/phase_matrix/...    32
# 2    /home/janjar/Dataset/Trainingset/phase_matrix/...     9
# 3    /home/janjar/Dataset/Trainingset/phase_matrix/...    27
# 4    /home/janjar/Dataset/Trainingset/phase_matrix/...    11
# 5    /home/janjar/Dataset/Trainingset/phase_matrix/...     5
# 6    /home/janjar/Dataset/Trainingset/phase_matrix/...    29
# 7    /home/janjar/Dataset/Trainingset/phase_matrix/...    30
# 8    /home/janjar/Dataset/Trainingset/phase_matrix/...    22
# 9    /home/janjar/Dataset/Trainingset/phase_matrix/...    10
# 10   /home/janjar/Dataset/Trainingset/phase_matrix/...    13
# 11   /home/janjar/Dataset/Trainingset/phase_matrix/...     7
# 12   /home/janjar/Dataset/Trainingset/phase_matrix/...     1
# 13   /home/janjar/Dataset/Trainingset/phase_matrix/...    17
# 14   /home/janjar/Dataset/Trainingset/phase_matrix/...    36
# 15   /home/janjar/Dataset/Trainingset/phase_matrix/...    24
# 16   /home/janjar/Dataset/Trainingset/phase_matrix/...    23
# 17   /home/janjar/Dataset/Trainingset/phase_matrix/...    35
# 18   /home/janjar/Dataset/Trainingset/phase_matrix/...     4
# 19   /home/janjar/Dataset/Trainingset/phase_matrix/...    11
# 20   /home/janjar/Dataset/Trainingset/phase_matrix/...    27
# 21   /home/janjar/Dataset/Trainingset/phase_matrix/...    35
# 22   /home/janjar/Dataset/Trainingset/phase_matrix/...    30
# 23   /home/janjar/Dataset/Trainingset/phase_matrix/...    22
# 24   /home/janjar/Dataset/Trainingset/phase_matrix/...    10
# 25   /home/janjar/Dataset/Trainingset/phase_matrix/...     4
# 26   /home/janjar/Dataset/Trainingset/phase_matrix/...    11
# 27   /home/janjar/Dataset/Trainingset/phase_matrix/...    11
# 28   /home/janjar/Dataset/Trainingset/phase_matrix/...     4
# 29   /home/janjar/Dataset/Trainingset/phase_matrix/...    28
# ..                                                 ...   ...
# 110  /home/janjar/Dataset/Trainingset/phase_matrix/...    33
# 111  /home/janjar/Dataset/Trainingset/phase_matrix/...    33
# 112  /home/janjar/Dataset/Trainingset/phase_matrix/...    34
# 113  /home/janjar/Dataset/Trainingset/phase_matrix/...     2
# 114  /home/janjar/Dataset/Trainingset/phase_matrix/...    32
# 115  /home/janjar/Dataset/Trainingset/phase_matrix/...     7
# 116  /home/janjar/Dataset/Trainingset/phase_matrix/...    27
# 117  /home/janjar/Dataset/Trainingset/phase_matrix/...    34
# 118  /home/janjar/Dataset/Trainingset/phase_matrix/...    19
# 119  /home/janjar/Dataset/Trainingset/phase_matrix/...    20
# 120  /home/janjar/Dataset/Trainingset/phase_matrix/...    36
# 121  /home/janjar/Dataset/Trainingset/phase_matrix/...    21
# 122  /home/janjar/Dataset/Trainingset/phase_matrix/...    20
# 123  /home/janjar/Dataset/Trainingset/phase_matrix/...     8
# 124  /home/janjar/Dataset/Trainingset/phase_matrix/...    18
# 125  /home/janjar/Dataset/Trainingset/phase_matrix/...    35
# 126  /home/janjar/Dataset/Trainingset/phase_matrix/...    30
# 127  /home/janjar/Dataset/Trainingset/phase_matrix/...    32
# 128  /home/janjar/Dataset/Trainingset/phase_matrix/...    11
# 129  /home/janjar/Dataset/Trainingset/phase_matrix/...     5
# 130  /home/janjar/Dataset/Trainingset/phase_matrix/...    32
# 131  /home/janjar/Dataset/Trainingset/phase_matrix/...    10
# 132  /home/janjar/Dataset/Trainingset/phase_matrix/...    24
# 133  /home/janjar/Dataset/Trainingset/phase_matrix/...    19
# 134  /home/janjar/Dataset/Trainingset/phase_matrix/...    36
# 135  /home/janjar/Dataset/Trainingset/phase_matrix/...    14
# 136  /home/janjar/Dataset/Trainingset/phase_matrix/...     8
# 137  /home/janjar/Dataset/Trainingset/phase_matrix/...    12
# 138  /home/janjar/Dataset/Trainingset/phase_matrix/...    33
# 139  /home/janjar/Dataset/Trainingset/phase_matrix/...    18
#
# [140 rows x 8 columns]

# %% [markdown]
# ### Saving the Dataframe into a pickle to use it for the Training

# %%
Dataset.to_pickle("/home/janjar/Dataset/Trainingset/Training_dataframe.pkl")
