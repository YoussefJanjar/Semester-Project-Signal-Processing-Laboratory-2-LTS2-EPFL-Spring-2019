# %% [markdown]
# # Creation of the Dataset

# %% [markdown]
# ### Importations

# %%
import numpy as np
import matplotlib.pyplot as plt
import IPython
import pyroomacoustics as pra
import pickle as pkl
import pandas as pd
from scipy.io import wavfile
from scipy.signal import fftconvolve
from scipy import signal
from matplotlib import gridspec

# %% [markdown]
# ### Function that computes the absorption out of the room dimensions and the RT60.

# %%
def compute_absorption(room_eadge,room_height,RT60):
    V = (room_eadge**2)*room_height
    S = 2*(room_eadge**2) + 4*(room_height**2)
    absr = 0.1611*(V/(S*RT60))
    return absr

# %% [markdown]
# ### Setting the different parameters for the rooms

# %%
#Here You should put the path to where the file wav is on the machine you are working on.
folder_path = "/home/janjar/Semester_Project/Dataset/GDWN/WGN.wav"
file_to_open = folder_path 

ang = (np.array([61.]) / 180.) * np.pi
distance = 1.0
a = np.array([5.,5.,3.])
b = np.array([6.,6.,3.])
dimensions = np.stack((a,b))
distances = np.array([1.,2.])
RT60 = np.array([0.2,0.3])

absorption_1 = compute_absorption(a[0],a[2],RT60[0])
absorption_2 = compute_absorption(b[0],b[2],RT60[1])
absorptions = np.array([absorption_1,absorption_2])
print(absorptions.shape)

snr = 1000.
fs,signal_wav = wavfile.read(file_to_open)
snrs = np.array([5,10,15,20])
print(fs)
# Out:
# (2,)
# 44100

# %% [markdown]
# ## Methode that generates a room out of the conditions given in argument.
# ### Returns the audio_signals for the 4 mics, the location of the source and the absorption of the room .

# %%
def generate_room_from_conditions(ang,distance,absorptions,snr,dimensions,typeofroom):
   
    room_dim = dimensions[typeofroom]
    room_eadge = room_dim[0]

    sf = (0.03*np.sqrt(2)/4)
    corners = np.array([[0,0],[0,room_eadge],[room_eadge,room_eadge],[room_eadge,0]]).T
    
    absr = absorptions[typeofroom]
    room = pra.Room.from_corners(corners, fs=fs , max_order=8 ,absorption=absorptions[typeofroom])
    room.extrude(3.)

    # Add sources of 1 second duration
    #room_dim = np.array([5,5,3])
    rng = np.random.RandomState(23)
    duration_samples = int(fs)


    source_location = room_dim / 2 + (distance * np.array([np.cos(ang), np.sin(ang),0.0]))
    source_signal = rng.randn(duration_samples)
    room.add_source(source_location, signal = signal_wav)
    print('Here is the source at this step:',source_location) 

    #We initiate the point of the Tethra then we scale them
    #and translate the origin of the Tethra to the center of the room.
    R = np.array([(sf*np.array([1,1,-1,-1]))+2.5,(sf*np.array([1,-1,1,-1]))+2.5,(sf*np.array([1,-1,-1,1]))+1.5])# [[x], [y], [z]]
    room.add_microphone_array(pra.MicrophoneArray(R,room.fs))
    room.image_source_model(use_libroom=True)

    #Visualization
    #fig, ax = room.plot(img_order=3)
    #fig.set_size_inches(18.5,10.5)

    room.simulate(snr = snr)
    #print('Here is the audio signal:',room.mic_array.signals[0][:5])
    return room,room.mic_array.signals,source_location,absr

# %% [markdown]
# ### Testing that generate_room works properly

# %%
ang = (np.array([61.]) / 180.) * np.pi
ang1 = (np.array([10.]) / 180.) * np.pi
room1,audio_signals,source_loc,t = generate_room_from_conditions(ang,distances[0],absorptions,snr,dimensions,0)
room2,audio_signals1,source_loc1,t1 = generate_room_from_conditions(ang1,distances[1],absorptions,snr,dimensions,1)
print(audio_signals[0,:].shape)
# Out:
# Here is the source at this step: [array([2.98480962]) array([3.37461971]) 1.5]
# Here is the source at this step: [array([4.96961551]) array([3.34729636]) 1.5]
# (49702,)

# %%
#Plotting the RIR for each microphone
room1.plot_rir()
fig = plt.gcf()
fig.set_size_inches(20, 10)

# %%
#Plotting the RIR for each microphone
room2.plot_rir()
fig = plt.gcf()
fig.set_size_inches(20, 10)

# %%
print(audio_signals1==audio_signals)
# Out:
# False
# /home/janjar/test/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Method that compute the phasematrix out of a signal and store it in the training folder.
# ### Returns the paths to the audio_file and the phase_matrix.

# %%
def generate_phasematrix_from_signals(signals,j):
    
    #Here also the path should be the folder you need the audio files to be stored on.
        path = "/home/janjar/Dataset/Trainingset/"   
        name_signals = 'audio_signals/audio_signals-{}'.format(j)
        fileName_audio = path + name_signals
        fileObject = open(fileName_audio, 'wb')
        pkl.dump(signals, fileObject)
        fileObject.close()                
    
        phase_matrix = np.zeros((4, 129, 390))
        
        #print("Ici elle doit etre vide",phase_matrix)
        for i in range(4):
            f, t, stft_mic0 = signal.stft(signals[i,:].astype(np.float32), fs)
            spectrum = stft_mic0
            print("shape of the STFT:",spectrum)
            magnitude = np.abs(spectrum)
            phase = np.angle(spectrum)
            print('Here is the phase:',phase.shape)
            x = phase.shape[0]
            y = phase.shape[1]
            #print("HERE IS THE SHAPE",phase.shape)
            #phase_matrix = np.empty((4, x, y))
            phase_matrix[i] = phase[:,:390]
        
        
        #print("Matrice finale",phase_matrix)
        path = "/home/janjar/Dataset/Trainingset/"   
        name_matrix = 'phase_matrix/Phase_matrix-{}'.format(j)
        fileName_matrix = path + name_matrix
        fileObject = open(fileName_matrix, 'wb')
        pkl.dump(phase_matrix, fileObject)
        fileObject.close()                    
        return fileName_audio,fileName_matrix,phase_matrix

# %% [markdown]
# ### Testing that generate_phasematrix works properly

# %%
path_to_audio,path_to_matrix,_ = generate_phasematrix_from_signals(audio_signals1,0)
# Out:
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)

# %%
np.array_equal(audio_signals, audio_signals1)
# Out:
# False

# %%
_,_,phase0 = generate_phasematrix_from_signals(audio_signals,0)
_,_,phase1 = generate_phasematrix_from_signals(audio_signals1,1)
# Out:
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)

# %%
print(phase0.shape,phase1.shape)
# Out:
# (4, 129, 390) (4, 129, 390)

# %%
np.array_equal(phase0, phase1)
# Out:
# False

# %% [markdown]
# ### Funtion to assign the right label to each angle.

# %%
def assign_label_to_anlges(angles):
	bins = np.linspace(0, 180, 37)
	label = np.digitize(angles, bins)
	return label

# %% [markdown]
# ## The main function that generate the entire Dataset set including the Dataframe to represent it.
# ### Return the Dataframe representing the training set.

# %%
def genere_dataset():
        index = 0
        df = pd.DataFrame(columns = ['Room','Array_position','Distance','Absorption','SNR','Audio_file','Phase_Matrix','Label'])
        snr = np.array([0,5,10,15,20]) #Comment this part to turn the snr into random assignment for each room
	#We iterate over the type of rooms (R1,R2).
        for i in range (2):          
	#We iterate over the distances from the microphones (1m,2m).	
            for j in range(2):
    #We iterate over the 5 different SNRS.       
                for l in range(5):    
	#We iterate on the 7 random positions of the source.		
                    for k in range(7):
                        print('Room:',index)
                        angles = np.random.uniform(low=0, high=180, size=(7,))
                        #print('Here are the angles for this Room:',angles) #Make the angles able to go to floats.
                        labels = assign_label_to_anlges(angles)
                        #print('Here are the labels for this Room:',labels) #Check if the labels match the angles.
                        azimuth = angles / 180. * np.pi 
                        #snr = snrs[np.random.randint(4,size = 1)] # Uncomment this part to turn the snr into random assignment for each room
                        _,signals,array_position,absr = generate_room_from_conditions(angles[k],distances[j],absorptions,snr[l],dimensions,i)
                        fileName_audio,fileName_matrix,_ = generate_phasematrix_from_signals(signals,index)
                        df = df.append({'Room':i,'Array_position':array_position,'Distance':distances[j],'Absorption':absr,'SNR':snr[l],'Audio_file':fileName_audio,'Phase_Matrix':fileName_matrix,'Label':labels[k]} , ignore_index=True)
                        index = index+1
        return df

# %%
Dataset = genere_dataset()
# Out:
# Room: 0
# Here is the source at this step: [2.52645088 1.50034989 1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 1
# Here is the source at this step: [1.53537324 2.23638055 1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 2
# Here is the source at this step: [2.83462877 1.55764997 1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 3
# Here is the source at this step: [1.57876229 2.1109999  1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 4
# Here is the source at this step: [2.92617194 1.59535782 1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 5
# Here is the source at this step: [1.90684087 1.69491476 1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 6
# Here is the source at this step: [1.77845309 3.19236555 1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 7
# Here is the source at this step: [1.58209563 2.89680168 1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 8
# Here is the source at this step: [2.83001182 3.4439768  1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 9
# Here is the source at this step: [2.04874477 1.60760507 1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 10
# Here is the source at this step: [3.41404791 2.09439377 1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 11
# Here is the source at this step: [3.49862184 2.55248254 1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 12
# Here is the source at this step: [2.80564668 1.547855   1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 13
# Here is the source at this step: [2.44458805 3.49846358 1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 14
# Here is the source at this step: [1.87694264 1.71782385 1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 15
# Here is the source at this step: [2.89053291 1.57941103 1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 16
# Here is the source at this step: [2.49261235 1.50002729 1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 17
# Here is the source at this step: [2.01134241 3.37247565 1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 18
# Here is the source at this step: [1.50398862 2.58922624 1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 19
# Here is the source at this step: [3.10592218 1.70447608 1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 20
# Here is the source at this step: [3.34792628 1.96988584 1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 21
# Here is the source at this step: [3.49973847 2.52286887 1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 22
# Here is the source at this step: [3.1684653  1.75625667 1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 23
# Here is the source at this step: [3.19635102 1.78229863 1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 24
# Here is the source at this step: [2.86542005 1.56915727 1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 25
# Here is the source at this step: [3.39604841 2.94395637 1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 26
# Here is the source at this step: [3.47727894 2.28804276 1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 27
# Here is the source at this step: [3.48841236 2.34820739 1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 28
# Here is the source at this step: [2.79311872 3.45607605 1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 29
# Here is the source at this step: [2.60166293 3.4948189  1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 30
# Here is the source at this step: [3.3638184  3.00380331 1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 31
# Here is the source at this step: [3.06677964 1.67613057 1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 32
# Here is the source at this step: [1.50283388 2.57523123 1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 33
# Here is the source at this step: [1.9680759  3.34679203 1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 34
# Here is the source at this step: [3.14537391 3.26386682 1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 35
# Here is the source at this step: [1.81570848 0.62070622 1.5       ]
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Room: 36
# Here is the source at this step: [4.18082369 3.58389655 1.5       ]
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Room: 37
# Here is the source at this step: [4.22215789 3.51694258 1.5       ]
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Room: 38
# Here is the source at this step: [0.50001558 2.50789424 1.5       ]
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Room: 39
# Here is the source at this step: [1.13019432 3.95726882 1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 40
# Here is the source at this step: [4.49996977 2.51099606 1.5       ]
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Room: 41
# Here is the source at this step: [3.6100237  0.83631512 1.5       ]
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Room: 42
# Here is the source at this step: [1.13486844 3.96164832 1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 43
# Here is the source at this step: [3.5566845  4.19806298 1.5       ]
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Room: 44
# Here is the source at this step: [2.1507041  0.53073811 1.5       ]
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Room: 45
# Here is the source at this step: [0.50085188 2.4416324  1.5       ]
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Room: 46
# Here is the source at this step: [0.88501538 1.32024381 1.5       ]
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Room: 47
# Here is the source at this step: [4.29072407 3.39067801 1.5       ]
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Room: 48
# Here is the source at this step: [2.70354665 4.48961523 1.5       ]
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Room: 49
# Here is the source at this step: [1.61925313 4.2956294  1.5       ]
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Room: 50
# Here is the source at this step: [1.8531471  0.60749337 1.5       ]
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Room: 51
# Here is the source at this step: [1.33780137 4.1276653  1.5       ]
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Room: 52
# Here is the source at this step: [0.7107262  1.60641213 1.5       ]
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Room: 53
# Here is the source at this step: [4.40873883 3.09725713 1.5       ]
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Room: 54
# Here is the source at this step: [3.58773807 0.82165978 1.5       ]
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Room: 55
# Here is the source at this step: [1.31152292 4.1085777  1.5       ]
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Room: 56
# Here is the source at this step: [3.18733549 4.37818261 1.5       ]
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Room: 57
# Here is the source at this step: [1.22081482 4.03742814 1.5       ]
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Room: 58
# Here is the source at this step: [1.83554261 4.38639773 1.5       ]
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Room: 59
# Here is the source at this step: [2.91967263 0.54452694 1.5       ]
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Room: 60
# Here is the source at this step: [0.5225484  2.20052517 1.5       ]
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Room: 61
# Here is the source at this step: [4.49738049 2.60232882 1.5       ]
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Room: 62
# Here is the source at this step: [0.51567431 2.2500969  1.5       ]
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Room: 63
# Here is the source at this step: [0.95969655 3.77572147 1.5       ]
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Room: 64
# Here is the source at this step: [0.61920203 3.18014631 1.5       ]
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Room: 65
# Here is the source at this step: [1.84894622 0.60893443 1.5       ]
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Room: 66
# Here is the source at this step: [3.95301404 3.87431808 1.5       ]
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Here is the phase: (129, 390)
# Room: 67
# Here is the source at this step: [2.80910192 4.47596964 1.5       ]
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Room: 68
# Here is the source at this step: [2.1977678  4.47703204 1.5       ]
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Room: 69
# Here is the source at this step: [2.46188006 4.49963668 1.5       ]
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Here is the phase: (129, 391)
# Room: 70
# Here is the source at this step: [2.35145644 2.23882246 1.5       ]
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Room: 71
# Here is the source at this step: [2.04398486 2.70668267 1.5       ]
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Room: 72
# Here is the source at this step: [3.17028441 3.98539496 1.5       ]
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Room: 73
# Here is the source at this step: [2.42393218 2.1825981  1.5       ]
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Room: 74
# Here is the source at this step: [3.27303026 3.96200544 1.5       ]
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Room: 75
# Here is the source at this step: [3.97015713 3.24247708 1.5       ]
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Room: 76
# Here is the source at this step: [2.93281621 3.99774062 1.5       ]
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Room: 77
# Here is the source at this step: [2.68185081 2.05195934 1.5       ]
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Room: 78
# Here is the source at this step: [2.36780353 3.77480812 1.5       ]
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Room: 79
# Here is the source at this step: [3.69989928 3.71424155 1.5       ]
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Room: 80
# Here is the source at this step: [3.06402169 2.00205149 1.5       ]
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Room: 81
# Here is the source at this step: [2.11373773 3.46318376 1.5       ]
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Room: 82
# Here is the source at this step: [3.52240084 2.14729996 1.5       ]
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Room: 83
# Here is the source at this step: [2.93143535 2.00235332 1.5       ]
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Room: 84
# Here is the source at this step: [2.01591787 2.82228572 1.5       ]
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Room: 85
# Here is the source at this step: [3.40332084 3.91505863 1.5       ]
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Room: 86
# Here is the source at this step: [2.01870037 3.19248643 1.5       ]
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Room: 87
# Here is the source at this step: [2.12493826 3.48401131 1.5       ]
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Room: 88
# Here is the source at this step: [2.14031642 3.51082693 1.5       ]
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Room: 89
# Here is the source at this step: [2.9905834  3.99995566 1.5       ]
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Room: 90
# Here is the source at this step: [3.81733384 2.42383562 1.5       ]
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Room: 91
# Here is the source at this step: [3.26017053 3.96556268 1.5       ]
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Room: 92
# Here is the source at this step: [2.44035464 2.17126779 1.5       ]
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Room: 93
# Here is the source at this step: [3.39668163 2.08204375 1.5       ]
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Room: 94
# Here is the source at this step: [2.40644056 2.19520985 1.5       ]
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Room: 95
# Here is the source at this step: [2.98755731 2.00007741 1.5       ]
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Room: 96
# Here is the source at this step: [2.06365655 3.35108538 1.5       ]
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Room: 97
# Here is the source at this step: [2.33773094 3.74926611 1.5       ]
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Room: 98
# Here is the source at this step: [2.61231932 3.92179374 1.5       ]
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Room: 99
# Here is the source at this step: [2.02023003 2.79987305 1.5       ]
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Room: 100
# Here is the source at this step: [2.80008643 2.02018646 1.5       ]
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Room: 101
# Here is the source at this step: [2.59727956 2.08467697 1.5       ]
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Room: 102
# Here is the source at this step: [2.90300792 2.00471485 1.5       ]
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Here is the phase: (129, 398)
# Room: 103
# Here is the source at this step: [3.75866025 2.34851353 1.5       ]
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Room: 104
# Here is the source at this step: [2.37851185 3.78342357 1.5       ]
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Room: 105
# Here is the source at this step: [1.00165651 2.91861641 1.5       ]
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Room: 106
# Here is the source at this step: [1.68117932 4.50356643 1.5       ]
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Room: 107
# Here is the source at this step: [4.99726019 3.10465051 1.5       ]
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Room: 108
# Here is the source at this step: [4.56440523 1.75395173 1.5       ]
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Room: 109
# Here is the source at this step: [2.95388436 1.00053173 1.5       ]
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Room: 110
# Here is the source at this step: [1.44747731 4.26082247 1.5       ]
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Room: 111
# Here is the source at this step: [4.25746372 1.44475564 1.5       ]
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Room: 112
# Here is the source at this step: [3.92708656 1.22785144 1.5       ]
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Room: 113
# Here is the source at this step: [1.20829471 3.8887025  1.5       ]
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Room: 114
# Here is the source at this step: [3.41551182 4.9563614  1.5       ]
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Room: 115
# Here is the source at this step: [4.60244853 4.19672833 1.5       ]
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Room: 116
# Here is the source at this step: [4.51016816 1.68874406 1.5       ]
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Room: 117
# Here is the source at this step: [2.96896662 1.00024078 1.5       ]
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Room: 118
# Here is the source at this step: [1.50119764 4.32423242 1.5       ]
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Room: 119
# Here is the source at this step: [1.7691997 4.5764297 1.5      ]
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Room: 120
# Here is the source at this step: [4.93459163 2.49269809 1.5       ]
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Room: 121
# Here is the source at this step: [3.7378849  1.14109552 1.5       ]
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Room: 122
# Here is the source at this step: [2.02934049 1.25133762 1.5       ]
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Room: 123
# Here is the source at this step: [3.40590343 4.95837749 1.5       ]
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Room: 124
# Here is the source at this step: [2.1458919 1.1915478 1.5      ]
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Room: 125
# Here is the source at this step: [1.0856623  2.42093941 1.5       ]
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Room: 126
# Here is the source at this step: [4.58179965 4.22389128 1.5       ]
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Room: 127
# Here is the source at this step: [3.10173372 1.00258911 1.5       ]
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Room: 128
# Here is the source at this step: [4.7415263  3.98340538 1.5       ]
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Room: 129
# Here is the source at this step: [1.16209956 3.78874709 1.5       ]
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Room: 130
# Here is the source at this step: [1.05808592 2.52149221 1.5       ]
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Room: 131
# Here is the source at this step: [4.56746201 4.24220081 1.5       ]
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Room: 132
# Here is the source at this step: [3.94594772 1.23784708 1.5       ]
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Room: 133
# Here is the source at this step: [1.05573957 2.53111688 1.5       ]
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Room: 134
# Here is the source at this step: [1.00636076 3.15938186 1.5       ]
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Room: 135
# Here is the source at this step: [4.21063585 4.5919676  1.5       ]
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Room: 136
# Here is the source at this step: [4.97539035 3.3127826  1.5       ]
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Room: 137
# Here is the source at this step: [4.27983976 1.46311673 1.5       ]
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Room: 138
# Here is the source at this step: [4.83632581 2.20759383 1.5       ]
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Here is the phase: (129, 400)
# Room: 139
# Here is the source at this step: [1.44810239 4.26159178 1.5       ]
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)
# Here is the phase: (129, 399)

# %%
Dataset
# Out:
#     Room                                 Array_position  Distance  Absorption  \
# 0      0  [2.5264508835827266, 1.5003498858312008, 1.5]       1.0    0.702471
# 1      0     [1.5353732403837514, 2.2363805495942, 1.5]       1.0    0.702471
# 2      0   [2.834628768393095, 1.5576499655840617, 1.5]       1.0    0.702471
# 3      0  [1.5787622897224167, 2.1109998956780145, 1.5]       1.0    0.702471
# 4      0  [2.9261719441007026, 1.5953578198749365, 1.5]       1.0    0.702471
# 5      0  [1.9068408652671156, 1.6949147617283398, 1.5]       1.0    0.702471
# 6      0  [1.7784530854902283, 3.1923655466308447, 1.5]       1.0    0.702471
# 7      0  [1.5820956342137538, 2.8968016825450076, 1.5]       1.0    0.702471
# 8      0  [2.8300118192271206, 3.4439768001229725, 1.5]       1.0    0.702471
# 9      0   [2.048744768108015, 1.6076050674224382, 1.5]       1.0    0.702471
# 10     0    [3.4140479144135782, 2.09439377451007, 1.5]       1.0    0.702471
# 11     0  [3.4986218419640203, 2.5524825375947837, 1.5]       1.0    0.702471
# 12     0   [2.805646679094582, 1.5478549965690869, 1.5]       1.0    0.702471
# 13     0   [2.4445880480677635, 3.498463577494472, 1.5]       1.0    0.702471
# 14     0   [1.8769426419196158, 1.717823850694812, 1.5]       1.0    0.702471
# 15     0  [2.8905329133743054, 1.5794110344071153, 1.5]       1.0    0.702471
# 16     0  [2.4926123450620095, 1.5000272890950888, 1.5]       1.0    0.702471
# 17     0   [2.011342408392205, 3.3724756490378796, 1.5]       1.0    0.702471
# 18     0  [1.5039886153476094, 2.5892262385334486, 1.5]       1.0    0.702471
# 19     0    [3.105922180162993, 1.704476077300924, 1.5]       1.0    0.702471
# 20     0  [3.3479262797758578, 1.9698858386484346, 1.5]       1.0    0.702471
# 21     0   [3.499738473272144, 2.5228688665981154, 1.5]       1.0    0.702471
# 22     0  [3.1684653031321885, 1.7562566716209205, 1.5]       1.0    0.702471
# 23     0  [3.1963510153581796, 1.7822986251861905, 1.5]       1.0    0.702471
# 24     0  [2.8654200509266996, 1.5691572708664863, 1.5]       1.0    0.702471
# 25     0    [3.396048405986074, 2.943956365119159, 1.5]       1.0    0.702471
# 26     0  [3.4772789398942656, 2.2880427551624147, 1.5]       1.0    0.702471
# 27     0    [3.488412364713758, 2.348207387264872, 1.5]       1.0    0.702471
# 28     0  [2.7931187162627724, 3.4560760525065275, 1.5]       1.0    0.702471
# 29     0   [2.601662929749728, 3.4948189024715512, 1.5]       1.0    0.702471
# ..   ...                                            ...       ...         ...
# 110    1   [1.4474773086498365, 4.260822466821893, 1.5]       2.0    0.537000
# 111    1   [4.257463715035421, 1.4447556444824117, 1.5]       2.0    0.537000
# 112    1  [3.9270865575631975, 1.2278514411072585, 1.5]       2.0    0.537000
# 113    1   [1.2082947066439844, 3.888702504643727, 1.5]       2.0    0.537000
# 114    1     [3.415511823347709, 4.95636139929673, 1.5]       2.0    0.537000
# 115    1    [4.602448530413712, 4.196728334825801, 1.5]       2.0    0.537000
# 116    1   [4.510168159883126, 1.6887440643126854, 1.5]       2.0    0.537000
# 117    1   [2.968966620272469, 1.0002407821583403, 1.5]       2.0    0.537000
# 118    1   [1.5011976425989269, 4.324232416703724, 1.5]       2.0    0.537000
# 119    1    [1.769199696098718, 4.576429704083411, 1.5]       2.0    0.537000
# 120    1     [4.9345916304445, 2.4926980944111397, 1.5]       2.0    0.537000
# 121    1   [3.737884898514342, 1.1410955171003327, 1.5]       2.0    0.537000
# 122    1  [2.0293404949175846, 1.2513376182941545, 1.5]       2.0    0.537000
# 123    1    [3.405903428866826, 4.958377493343445, 1.5]       2.0    0.537000
# 124    1   [2.145891897002954, 1.1915478031214684, 1.5]       2.0    0.537000
# 125    1  [1.0856622985970665, 2.4209394116438823, 1.5]       2.0    0.537000
# 126    1    [4.581799653541156, 4.223891276240288, 1.5]       2.0    0.537000
# 127    1    [3.101733719972148, 1.002589113321791, 1.5]       2.0    0.537000
# 128    1    [4.741526300919276, 3.983405380911872, 1.5]       2.0    0.537000
# 129    1  [1.1620995587435181, 3.7887470874933418, 1.5]       2.0    0.537000
# 130    1    [1.058085920194178, 2.521492208368654, 1.5]       2.0    0.537000
# 131    1    [4.567462006143863, 4.242200812789726, 1.5]       2.0    0.537000
# 132    1    [3.94594772487882, 1.2378470833107065, 1.5]       2.0    0.537000
# 133    1  [1.0557395706962804, 2.5311168769898877, 1.5]       2.0    0.537000
# 134    1   [1.0063607589414911, 3.159381857536085, 1.5]       2.0    0.537000
# 135    1   [4.210635852269322, 4.5919675980371375, 1.5]       2.0    0.537000
# 136    1   [4.975390352545619, 3.3127826003307947, 1.5]       2.0    0.537000
# 137    1     [4.279839760335823, 1.46311672926551, 1.5]       2.0    0.537000
# 138    1   [4.836325805137082, 2.2075938305467027, 1.5]       2.0    0.537000
# 139    1    [1.448102393226965, 4.261591779496096, 1.5]       2.0    0.537000
#
#     SNR                                         Audio_file  \
# 0     0  /home/janjar/Dataset/Trainingset/audio_signals...
# 1     0  /home/janjar/Dataset/Trainingset/audio_signals...
# 2     0  /home/janjar/Dataset/Trainingset/audio_signals...
# 3     0  /home/janjar/Dataset/Trainingset/audio_signals...
# 4     0  /home/janjar/Dataset/Trainingset/audio_signals...
# 5     0  /home/janjar/Dataset/Trainingset/audio_signals...
# 6     0  /home/janjar/Dataset/Trainingset/audio_signals...
# 7     5  /home/janjar/Dataset/Trainingset/audio_signals...
# 8     5  /home/janjar/Dataset/Trainingset/audio_signals...
# 9     5  /home/janjar/Dataset/Trainingset/audio_signals...
# 10    5  /home/janjar/Dataset/Trainingset/audio_signals...
# 11    5  /home/janjar/Dataset/Trainingset/audio_signals...
# 12    5  /home/janjar/Dataset/Trainingset/audio_signals...
# 13    5  /home/janjar/Dataset/Trainingset/audio_signals...
# 14   10  /home/janjar/Dataset/Trainingset/audio_signals...
# 15   10  /home/janjar/Dataset/Trainingset/audio_signals...
# 16   10  /home/janjar/Dataset/Trainingset/audio_signals...
# 17   10  /home/janjar/Dataset/Trainingset/audio_signals...
# 18   10  /home/janjar/Dataset/Trainingset/audio_signals...
# 19   10  /home/janjar/Dataset/Trainingset/audio_signals...
# 20   10  /home/janjar/Dataset/Trainingset/audio_signals...
# 21   15  /home/janjar/Dataset/Trainingset/audio_signals...
# 22   15  /home/janjar/Dataset/Trainingset/audio_signals...
# 23   15  /home/janjar/Dataset/Trainingset/audio_signals...
# 24   15  /home/janjar/Dataset/Trainingset/audio_signals...
# 25   15  /home/janjar/Dataset/Trainingset/audio_signals...
# 26   15  /home/janjar/Dataset/Trainingset/audio_signals...
# 27   15  /home/janjar/Dataset/Trainingset/audio_signals...
# 28   20  /home/janjar/Dataset/Trainingset/audio_signals...
# 29   20  /home/janjar/Dataset/Trainingset/audio_signals...
# ..   ..                                                ...
# 110   0  /home/janjar/Dataset/Trainingset/audio_signals...
# 111   0  /home/janjar/Dataset/Trainingset/audio_signals...
# 112   5  /home/janjar/Dataset/Trainingset/audio_signals...
# 113   5  /home/janjar/Dataset/Trainingset/audio_signals...
# 114   5  /home/janjar/Dataset/Trainingset/audio_signals...
# 115   5  /home/janjar/Dataset/Trainingset/audio_signals...
# 116   5  /home/janjar/Dataset/Trainingset/audio_signals...
# 117   5  /home/janjar/Dataset/Trainingset/audio_signals...
# 118   5  /home/janjar/Dataset/Trainingset/audio_signals...
# 119  10  /home/janjar/Dataset/Trainingset/audio_signals...
# 120  10  /home/janjar/Dataset/Trainingset/audio_signals...
# 121  10  /home/janjar/Dataset/Trainingset/audio_signals...
# 122  10  /home/janjar/Dataset/Trainingset/audio_signals...
# 123  10  /home/janjar/Dataset/Trainingset/audio_signals...
# 124  10  /home/janjar/Dataset/Trainingset/audio_signals...
# 125  10  /home/janjar/Dataset/Trainingset/audio_signals...
# 126  15  /home/janjar/Dataset/Trainingset/audio_signals...
# 127  15  /home/janjar/Dataset/Trainingset/audio_signals...
# 128  15  /home/janjar/Dataset/Trainingset/audio_signals...
# 129  15  /home/janjar/Dataset/Trainingset/audio_signals...
# 130  15  /home/janjar/Dataset/Trainingset/audio_signals...
# 131  15  /home/janjar/Dataset/Trainingset/audio_signals...
# 132  15  /home/janjar/Dataset/Trainingset/audio_signals...
# 133  20  /home/janjar/Dataset/Trainingset/audio_signals...
# 134  20  /home/janjar/Dataset/Trainingset/audio_signals...
# 135  20  /home/janjar/Dataset/Trainingset/audio_signals...
# 136  20  /home/janjar/Dataset/Trainingset/audio_signals...
# 137  20  /home/janjar/Dataset/Trainingset/audio_signals...
# 138  20  /home/janjar/Dataset/Trainingset/audio_signals...
# 139  20  /home/janjar/Dataset/Trainingset/audio_signals...
#
#                                           Phase_Matrix Label
# 0    /home/janjar/Dataset/Trainingset/phase_matrix/...    35
# 1    /home/janjar/Dataset/Trainingset/phase_matrix/...    14
# 2    /home/janjar/Dataset/Trainingset/phase_matrix/...    20
# 3    /home/janjar/Dataset/Trainingset/phase_matrix/...    36
# 4    /home/janjar/Dataset/Trainingset/phase_matrix/...    19
# 5    /home/janjar/Dataset/Trainingset/phase_matrix/...    16
# 6    /home/janjar/Dataset/Trainingset/phase_matrix/...     3
# 7    /home/janjar/Dataset/Trainingset/phase_matrix/...    16
# 8    /home/janjar/Dataset/Trainingset/phase_matrix/...     6
# 9    /home/janjar/Dataset/Trainingset/phase_matrix/...    32
# 10   /home/janjar/Dataset/Trainingset/phase_matrix/...    29
# 11   /home/janjar/Dataset/Trainingset/phase_matrix/...     8
# 12   /home/janjar/Dataset/Trainingset/phase_matrix/...    20
# 13   /home/janjar/Dataset/Trainingset/phase_matrix/...    36
# 14   /home/janjar/Dataset/Trainingset/phase_matrix/...    11
# 15   /home/janjar/Dataset/Trainingset/phase_matrix/...    10
# 16   /home/janjar/Dataset/Trainingset/phase_matrix/...    10
# 17   /home/janjar/Dataset/Trainingset/phase_matrix/...    35
# 18   /home/janjar/Dataset/Trainingset/phase_matrix/...    17
# 19   /home/janjar/Dataset/Trainingset/phase_matrix/...    33
# 20   /home/janjar/Dataset/Trainingset/phase_matrix/...    22
# 21   /home/janjar/Dataset/Trainingset/phase_matrix/...    24
# 22   /home/janjar/Dataset/Trainingset/phase_matrix/...    29
# 23   /home/janjar/Dataset/Trainingset/phase_matrix/...    19
# 24   /home/janjar/Dataset/Trainingset/phase_matrix/...    12
# 25   /home/janjar/Dataset/Trainingset/phase_matrix/...    21
# 26   /home/janjar/Dataset/Trainingset/phase_matrix/...     3
# 27   /home/janjar/Dataset/Trainingset/phase_matrix/...    16
# 28   /home/janjar/Dataset/Trainingset/phase_matrix/...    21
# 29   /home/janjar/Dataset/Trainingset/phase_matrix/...    36
# ..                                                 ...   ...
# 110  /home/janjar/Dataset/Trainingset/phase_matrix/...    24
# 111  /home/janjar/Dataset/Trainingset/phase_matrix/...    33
# 112  /home/janjar/Dataset/Trainingset/phase_matrix/...    13
# 113  /home/janjar/Dataset/Trainingset/phase_matrix/...     1
# 114  /home/janjar/Dataset/Trainingset/phase_matrix/...    10
# 115  /home/janjar/Dataset/Trainingset/phase_matrix/...    11
# 116  /home/janjar/Dataset/Trainingset/phase_matrix/...    13
# 117  /home/janjar/Dataset/Trainingset/phase_matrix/...    17
# 118  /home/janjar/Dataset/Trainingset/phase_matrix/...    24
# 119  /home/janjar/Dataset/Trainingset/phase_matrix/...    14
# 120  /home/janjar/Dataset/Trainingset/phase_matrix/...    36
# 121  /home/janjar/Dataset/Trainingset/phase_matrix/...     2
# 122  /home/janjar/Dataset/Trainingset/phase_matrix/...    21
# 123  /home/janjar/Dataset/Trainingset/phase_matrix/...    28
# 124  /home/janjar/Dataset/Trainingset/phase_matrix/...    14
# 125  /home/janjar/Dataset/Trainingset/phase_matrix/...    21
# 126  /home/janjar/Dataset/Trainingset/phase_matrix/...     3
# 127  /home/janjar/Dataset/Trainingset/phase_matrix/...    10
# 128  /home/janjar/Dataset/Trainingset/phase_matrix/...     3
# 129  /home/janjar/Dataset/Trainingset/phase_matrix/...     1
# 130  /home/janjar/Dataset/Trainingset/phase_matrix/...    35
# 131  /home/janjar/Dataset/Trainingset/phase_matrix/...     1
# 132  /home/janjar/Dataset/Trainingset/phase_matrix/...     9
# 133  /home/janjar/Dataset/Trainingset/phase_matrix/...    28
# 134  /home/janjar/Dataset/Trainingset/phase_matrix/...    14
# 135  /home/janjar/Dataset/Trainingset/phase_matrix/...    22
# 136  /home/janjar/Dataset/Trainingset/phase_matrix/...    18
# 137  /home/janjar/Dataset/Trainingset/phase_matrix/...     5
# 138  /home/janjar/Dataset/Trainingset/phase_matrix/...    22
# 139  /home/janjar/Dataset/Trainingset/phase_matrix/...     6
#
# [140 rows x 8 columns]

# %% [markdown]
# ### Saving the Dataframe into a pickle to use it for the Training

# %%
Dataset.to_pickle("/home/janjar/Dataset/Trainingset/Training_dataframe.pkl")
